# %% [markdown]
# K-Nearest Neighbors (KNN)

# %%
import numpy as np
import pandas as pd

from rice_ml.supervised_learning import KNN, KNNRegressor

import matplotlib.pyplot as plt

from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, mean_squared_error

# %%
columns = ["fixed acidity","volatile acidity","citric acid","residual sugar",
           "chlorides","free sulfur dioxide","total sulfur dioxide","density",
           "pH","sulphates","alcohol","quality"
]

df1 = pd.read_csv('winequality-red.csv', header=None, names=columns)

df2 = pd.read_csv('winequality-white.csv', header=None, names=columns)

df = pd.concat([df1, df2], axis=0, ignore_index=True) 

df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 6492            6.2              0.21         0.29             1.6      0.039
# 6493            6.6              0.32         0.36             8.0      0.047
# 6494            6.5              0.24         0.19             1.2      0.041
# 6495            5.5              0.29         0.30             1.1      0.022
# 6496            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
y = df['high_quality'] = (df['quality'] >= 7)
X = df.drop(['quality', 'high_quality'], axis=1)
print(df['quality'].value_counts())
print(df['high_quality'].value_counts())

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, random_state=35
)
X_reg_train, X_reg_test, y_reg_train, y_reg_test = train_test_split(
    X, df['quality'], test_size=0.2, random_state=35)

# Standardize features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)
X_reg_train_scaled = scaler.fit_transform(X_reg_train)
X_reg_test_scaled = scaler.transform(X_reg_test)
# Out:
# quality
# 6    2836
# 5    2138
# 7    1079
# 4     216
# 8     193
# 3      30
# 9       5
# Name: count, dtype: int64
# high_quality
# False    5220
# True     1277
# Name: count, dtype: int64

# %%
model = KNN(k=3)
model.train(X_train_scaled, y_train)
regmodel = KNNRegressor(k=3)
regmodel.train(X_reg_train_scaled, y_reg_train)

# %%
y_pred = model.predict(X_test)

accuracy = np.mean(y_pred == y_test)
print(f"Test Accuracy: {accuracy:.2%}")

y_reg_pred = regmodel.predict(X_reg_test)

print(f'Mean Squared Error: {mean_squared_error(y_reg_test, y_reg_pred):.4f}')
# Out:
# Test Accuracy: 77.46%
# Mean Squared Error: 6.4680
